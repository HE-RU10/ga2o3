# %%
#neighbor_list analysis defects
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os 
# %matplotlib inline
import seaborn as sns

# %%
path1='/home/heruhe/Desktop/Ga2o3/cascade/5type_overlapping/500ev/out'
path1='/home/heruhe/Desktop/Ga2o3/cascade/5type/1500ev/anneal'
natom=81920
os.chdir(path1)

# %%
#ndf=pd.read_csv('ndf_100.csv')
ndf=pd.read_csv('ndf8.csv')
ndf.drop(ndf.columns[0],axis=1,inplace=True)

ndf.iloc[:,5:]
# Out:
#          n1        d1   n2        d2   n3        d3   n4        d4   n5  \
# 0       4.0  1.885591  3.0  1.961198  5.0  2.022158  3.0  2.031709  5.0
# 1       4.0  1.908598  3.0  1.973168  3.0  1.991819  5.0  2.025397  5.0
# 2       4.0  1.771709  4.0  1.844881  5.0  1.912283  3.0  1.954933  1.0
# 3       3.0  1.795889  4.0  1.854493  5.0  1.871627  4.0  1.959677  1.0
# 4       3.0  1.861054  3.0  1.963923  4.0  1.976278  5.0  2.074958  5.0
# ...     ...       ...  ...       ...  ...       ...  ...       ...  ...
# 159995  1.0  1.826367  1.0  1.873736  2.0  1.967223  3.0  2.759896  3.0
# 159996  1.0  1.949934  2.0  2.033300  2.0  2.103690  2.0  2.169612  3.0
# 159997  1.0  1.900793  2.0  2.047902  2.0  2.065106  2.0  2.150310  3.0
# 159998  1.0  1.841089  2.0  1.864802  2.0  2.016357  5.0  2.678210  4.0
# 159999  1.0  1.889412  2.0  1.891225  2.0  1.930263  5.0  2.577494  4.0
#
#               d5   n6        d6
# 0       2.180322  5.0  2.222636
# 1       2.026355  5.0  2.372470
# 2       3.053510  1.0  3.132078
# 3       3.045712  1.0  3.194788
# 4       2.140718  5.0  2.239030
# ...          ...  ...       ...
# 159995  2.764494  5.0  2.860395
# 159996  2.577494  5.0  2.608033
# 159997  2.678210  5.0  2.686604
# 159998  2.812068  5.0  2.839936
# 159999  2.680245  4.0  2.701131
#
# [160000 rows x 12 columns]

# %%
##Ga1 perfect crystal

nga1=ndf[ndf['Particle Type']==1] #all Ga1 df
nga1['nsum4']= nga1.apply(lambda row: row['n1'] + row['n2']+row['n3']+row['n4'], axis=1)
nga1['nsum6']= nga1.apply(lambda row: row['n1'] + row['n2']+row['n3']+row['n4']+row['n5']+row['n6'], axis=1)

npga1=nga1[(nga1['nsum4']==16)|(nga1['nsum6']==25)] #perfect Ga1 crystal
print(len(npga1))
# Out:
# /tmp/ipykernel_1581569/2453449539.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nga1['nsum4']= nga1.apply(lambda row: row['n1'] + row['n2']+row['n3']+row['n4'], axis=1)
# 31921
# /tmp/ipykernel_1581569/2453449539.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nga1['nsum6']= nga1.apply(lambda row: row['n1'] + row['n2']+row['n3']+row['n4']+row['n5']+row['n6'], axis=1)

# %%
##Ga2 perfect crystal
nga2=ndf[ndf['Particle Type']==2] #all Ga2 df
nga2['nsum4']= nga2.apply(lambda row: row['n1'] + row['n2']+row['n3']+row['n4'], axis=1)
nga2['nsum6']= nga2.apply(lambda row: row['n1'] + row['n2']+row['n3']+row['n4']+row['n5']+row['n6'], axis=1)
npga2=nga2[(nga2['nsum4']==16)|(nga2['nsum6']==25)] #Ga2 perfect crystal df
print(len(npga2))
# Out:
# /tmp/ipykernel_1581569/1452047637.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nga2['nsum4']= nga2.apply(lambda row: row['n1'] + row['n2']+row['n3']+row['n4'], axis=1)
# 31924
# /tmp/ipykernel_1581569/1452047637.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nga2['nsum6']= nga2.apply(lambda row: row['n1'] + row['n2']+row['n3']+row['n4']+row['n5']+row['n6'], axis=1)

# %%
ndga1=nga1[~nga1.isin(npga1)].dropna()#Ga1 defects
dropl=[]
for i in ndga1['Particle Identifier']:
    x=ndga1[ndga1['Particle Identifier']==i]['x'].values[0]
    z=ndga1[ndga1['Particle Identifier']==i]['z'].values[0]
    n=len(npga2[(abs(npga2['x']-x)<0.9)&(abs(npga2['z']-z)<0.9)])+len(npga1[(abs(npga1['x']-x)<0.9)&(abs(npga1['z']-z)<0.9)])  
    if n>2:
        print(i,n)
        dropl.append(int(i-1))
ndga1 = ndga1.drop(index=dropl)
print(len(ndga1))
ndga1.iloc[:,0:]
# Out:
# 68264.0 39
# 75807.0 39
# 76247.0 38
# 76267.0 38
# 76567.0 39
# 83424.0 37
# 83427.0 38
# 83807.0 37
# 83824.0 37
# 83827.0 37
# 83863.0 39
# 84188.0 39
# 84223.0 38
# 91384.0 35
# 91764.0 35
# 91767.0 39
# 91808.0 37
# 91823.0 37
# 91863.0 37
# 92188.0 36
# 92203.0 37
# 92204.0 35
# 92207.0 37
# 92208.0 37
# 92243.0 37
# 92564.0 35
# 92568.0 36
# 92607.0 5
# 99803.0 16
# 99828.0 37
# 100127.0 38
# 100183.0 36
# 100207.0 38
# 100224.0 38
# 100263.0 39
# 100563.0 35
# 100564.0 37
# 100567.0 36
# 100568.0 39
# 100587.0 36
# 100927.0 38
# 100963.0 36
# 108148.0 34
# 108208.0 38
# 108548.0 29
# 108583.0 35
# 108584.0 39
# 108608.0 38
# 108928.0 34
# 108947.0 38
# 108948.0 38
# 108963.0 35
# 109327.0 38
# 116948.0 38
# 117327.0 39
# 124563.0 38
# 124583.0 38
# 125328.0 39
# 132528.0 39
# 20
#         Particle Identifier  Particle Type          x          y          z  \
# 75442               75443.0            1.0  75.718447  49.676868  62.285769
# 84202               84203.0            1.0  66.374277  57.658122  71.195382
# 91767               91768.0            1.0  60.374087  55.821538  75.436928
# 91787               91788.0            1.0  60.507272  58.850555  75.305095
# 91803               91804.0            1.0  66.295805  60.523281  73.911983
# 91823               91824.0            1.0  63.313947  60.506668  72.676055
# 92163               92164.0            1.0  54.788887  66.885407  77.192349
# 92262               92263.0            1.0  72.553155  65.312888  75.440820
# 92603               92604.0            1.0  63.477004  69.827619  72.712641
# 92963               92964.0            1.0  51.313301  76.056969  75.609078
# 100183             100184.0            1.0  54.194319  66.849989  80.122582
# 100207             100208.0            1.0  69.316633  65.306810  76.926084
# 100302             100303.0            1.0  87.748518  65.107384  77.064786
# 100603             100604.0            1.0  63.312028  63.453438  78.195796
# 100963             100964.0            1.0  54.179171  76.143618  80.071630
# 109327             109328.0            1.0  48.026734  80.687087  81.339582
# 109362             109363.0            1.0  50.892929  80.747219  85.932298
# 116262             116263.0            1.0  75.670711  65.152302  91.926774
# 117327             117328.0            1.0  48.156734  80.842953  87.550647
# 124202             124203.0            1.0  63.508230  62.043074  94.778692
#
#          n1        d1   n2        d2   n3        d3   n4        d4   n5  \
# 75442   3.0  1.800277  3.0  1.837102  3.0  1.883664  5.0  1.917477  2.0
# 84202   4.0  1.897517  3.0  1.908672  3.0  1.966435  4.0  2.078739  4.0
# 91767   4.0  1.830451  4.0  1.921618  4.0  1.999768  5.0  2.012497  5.0
# 91787   4.0  1.932997  4.0  1.957004  5.0  2.014170  4.0  2.056830  4.0
# 91803   4.0  1.916668  4.0  1.966475  4.0  2.005866  5.0  2.033616  4.0
# 91823   3.0  1.835009  5.0  1.845147  4.0  1.847116  3.0  1.900754  2.0
# 92163   5.0  1.823007  4.0  1.888216  4.0  1.920036  4.0  1.926795  4.0
# 92262   3.0  1.929714  3.0  1.936716  4.0  1.987512  4.0  1.997057  3.0
# 92603   3.0  1.866467  5.0  1.872539  3.0  1.940579  3.0  1.968244  1.0
# 92963   5.0  1.842746  3.0  1.846987  3.0  1.893755  3.0  1.894699  1.0
# 100183  3.0  1.911345  3.0  1.953603  4.0  1.976159  4.0  2.018151  4.0
# 100207  3.0  1.846757  5.0  1.881103  3.0  1.904940  3.0  2.088181  5.0
# 100302  3.0  1.817621  3.0  1.876326  3.0  1.877480  5.0  1.953907  1.0
# 100603  3.0  1.834792  4.0  1.882897  5.0  1.912242  3.0  1.997554  3.0
# 100963  4.0  1.936390  4.0  2.022879  4.0  2.027959  3.0  2.058813  5.0
# 109327  3.0  1.887969  4.0  1.948598  3.0  1.955789  4.0  1.998282  4.0
# 109362  3.0  1.816869  5.0  1.889778  3.0  1.956243  3.0  1.964227  2.0
# 116262  3.0  1.796801  3.0  1.850666  3.0  1.880016  5.0  2.051819  2.0
# 117327  3.0  1.895160  3.0  1.925291  4.0  1.959318  4.0  1.982412  4.0
# 124202  3.0  1.844790  3.0  1.871687  3.0  1.874940  5.0  1.956367  2.0
#
#               d5   n6        d6  nsum4  nsum6
# 75442   2.431797  2.0  2.503351   14.0   18.0
# 84202   2.092106  4.0  2.207318   14.0   22.0
# 91767   2.128488  4.0  2.447799   17.0   26.0
# 91787   2.152564  5.0  2.335801   17.0   26.0
# 91803   2.120506  5.0  2.167382   17.0   26.0
# 91823   3.027938  1.0  3.065708   15.0   18.0
# 92163   2.267653  2.0  2.733745   17.0   23.0
# 92262   2.009961  5.0  2.023395   14.0   22.0
# 92603   3.075501  1.0  3.179291   14.0   16.0
# 92963   3.157034  2.0  3.168850   14.0   17.0
# 100183  2.029224  4.0  2.090102   14.0   22.0
# 100207  2.573729  1.0  3.158662   14.0   20.0
# 100302  2.477521  2.0  2.619912   14.0   17.0
# 100603  2.340112  3.0  2.860419   15.0   21.0
# 100963  2.085856  3.0  2.159331   15.0   23.0
# 109327  2.086815  4.0  2.153278   14.0   22.0
# 109362  2.522029  1.0  3.013370   14.0   17.0
# 116262  2.458158  1.0  2.486252   14.0   17.0
# 117327  2.167495  4.0  2.379102   14.0   22.0
# 124202  2.406419  2.0  2.609623   14.0   18.0

# %%
#Ga2 defects

ndga2=nga2[~nga2.isin(npga2)].dropna()#Ga2 defects
dropl=[]
for i in ndga2['Particle Identifier']:
    x=ndga2[ndga2['Particle Identifier']==i]['x'].values[0]
    z=ndga2[ndga2['Particle Identifier']==i]['z'].values[0]
    n=len(npga2[(abs(npga2['x']-x)<0.9)&(abs(npga2['z']-z)<0.9)])+len(npga1[(abs(npga1['x']-x)<0.9)&(abs(npga1['z']-z)<0.9)])    
    if n>2:
        print(i,n)
        dropl.append(int(i-1))
ndga2 = ndga2.drop(index=dropl)
print(len(ndga2))

ndga2.iloc[:,0:]
# Out:
# 75442.0 39
# 75821.0 38
# 76201.0 38
# 76266.0 38
# 76645.0 39
# 76646.0 38
# 83425.0 37
# 83805.0 37
# 83806.0 39
# 83821.0 38
# 83825.0 37
# 84185.0 39
# 84186.0 39
# 84266.0 38
# 84646.0 38
# 91765.0 35
# 91766.0 9
# 91785.0 35
# 91806.0 38
# 91826.0 38
# 92126.0 39
# 92185.0 35
# 92186.0 36
# 92221.0 35
# 92222.0 38
# 92566.0 36
# 92585.0 35
# 99761.0 38
# 99762.0 36
# 99782.0 36
# 100126.0 38
# 100145.0 39
# 100146.0 38
# 100166.0 35
# 100181.0 35
# 100186.0 38
# 100201.0 26
# 100202.0 37
# 100205.0 38
# 100221.0 37
# 100226.0 38
# 100241.0 39
# 100262.0 39
# 100302.0 39
# 100566.0 38
# 100601.0 37
# 100605.0 37
# 100606.0 38
# 100625.0 37
# 100962.0 34
# 100965.0 38
# 100985.0 38
# 108261.0 39
# 108546.0 38
# 108562.0 39
# 108602.0 38
# 108622.0 38
# 108945.0 39
# 108981.0 36
# 116262.0 39
# 116561.0 39
# 117325.0 39
# 117326.0 39
# 124146.0 39
# 124202.0 39
# 124561.0 39
# 10
#         Particle Identifier  Particle Type          x          y          z  \
# 91800               91801.0            2.0  63.526807  57.413369  72.663803
# 91820               91821.0            2.0  60.484689  59.019188  72.425631
# 92201               92202.0            2.0  65.216248  62.137507  70.976047
# 100221             100222.0            2.0  66.086101  63.722154  74.058297
# 100561             100562.0            2.0  51.041481  69.983646  93.132589
# 100621             100622.0            2.0  66.381539  69.878186  74.036794
# 100960             100961.0            2.0  49.135424  76.187870  78.533522
# 108180             108181.0            2.0  51.144350  66.824655  81.661123
# 108925             108926.0            2.0  45.542670  80.845877  88.832333
# 108945             108946.0            2.0  48.021204  80.688041  84.371901
#
#          n1        d1   n2        d2   n3        d3   n4        d4   n5  \
# 91800   5.0  1.750928  3.0  1.839322  3.0  1.892345  3.0  1.930271  1.0
# 91820   3.0  1.881268  4.0  1.936318  4.0  1.967568  4.0  1.971094  4.0
# 92201   5.0  1.749121  5.0  1.833251  4.0  1.986668  4.0  1.991668  1.0
# 100221  5.0  1.917019  5.0  1.924637  4.0  1.956154  4.0  2.008970  4.0
# 100561  3.0  1.828738  3.0  1.859624  3.0  1.866105  5.0  1.894170  2.0
# 100621  5.0  1.847031  4.0  1.955816  5.0  2.030954  4.0  2.042526  4.0
# 100960  4.0  1.756784  5.0  1.874543  4.0  1.911423  5.0  1.937678  1.0
# 108180  3.0  1.795302  5.0  1.796088  4.0  1.882806  3.0  2.020023  1.0
# 108925  3.0  1.812250  3.0  1.866575  5.0  1.949325  3.0  1.967876  2.0
# 108945  4.0  1.900252  4.0  1.951929  4.0  1.982745  5.0  2.006993  4.0
#
#               d5   n6        d6  nsum4  nsum6
# 91800   3.100638  1.0  3.113390   14.0   16.0
# 91820   2.058868  3.0  2.104578   15.0   22.0
# 92201   3.027938  1.0  3.068513   18.0   20.0
# 100221  2.210671  5.0  2.443590   18.0   27.0
# 100561  2.399530  1.0  2.494837   14.0   17.0
# 100621  2.080188  4.0  2.197884   18.0   26.0
# 100960  3.159027  1.0  3.240611   18.0   20.0
# 108180  3.031701  1.0  3.130325   15.0   17.0
# 108925  2.748361  3.0  2.790395   14.0   19.0
# 108945  2.007495  5.0  2.190672   17.0   26.0

# %%
##O1 perfect crystal
no1=ndf[ndf['Particle Type']==3] #all O1
no1['nsum3']= no1.apply(lambda row: row['n1'] + row['n2']+row['n3'], axis=1)
no1['nsum4']= no1.apply(lambda row: row['n1'] + row['n2']+row['n3']+row['n4'], axis=1) 
npo1=no1[(no1['nsum3']==5)|(no1['nsum3']==4)|(no1['nsum4']==7)] #perfect O1 
print(len(npo1))
# Out:
# /tmp/ipykernel_1581569/3127756981.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no1['nsum3']= no1.apply(lambda row: row['n1'] + row['n2']+row['n3'], axis=1)
# 31984
# /tmp/ipykernel_1581569/3127756981.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no1['nsum4']= no1.apply(lambda row: row['n1'] + row['n2']+row['n3']+row['n4'], axis=1)

# %%
##O2 perfect crystal
no2=ndf[ndf['Particle Type']==4]
no2['nsum3']= no2.apply(lambda row: row['n1'] + row['n2']+row['n3'], axis=1)
no2['nsum4']= no2.apply(lambda row: row['n1'] + row['n2']+row['n3']+row['n4'], axis=1) 
npo2=no2[(no2['nsum3']==5)|(no2['nsum3']==4)|(no2['nsum4']==7)] #perfect O2
print(len(npo2))
# Out:
# /tmp/ipykernel_1581569/259496204.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no2['nsum3']= no2.apply(lambda row: row['n1'] + row['n2']+row['n3'], axis=1)
# 31989
# /tmp/ipykernel_1581569/259496204.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no2['nsum4']= no2.apply(lambda row: row['n1'] + row['n2']+row['n3']+row['n4'], axis=1)

# %%
##O3 perfect crystal
no3=ndf[ndf['Particle Type']==5]
no3['nsum3']= no3.apply(lambda row: row['n1'] + row['n2']+row['n3'], axis=1)
no3['nsum4']= no3.apply(lambda row: row['n1'] + row['n2']+row['n3']+row['n4'], axis=1) 
npo3=no3[(no3['nsum3']==5)|(no3['nsum3']==4)|(no3['nsum4']==7)] #perfect O3 
print(len(npo3))
# Out:
# /tmp/ipykernel_1581569/2292110095.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no3['nsum3']= no3.apply(lambda row: row['n1'] + row['n2']+row['n3'], axis=1)
# 31982
# /tmp/ipykernel_1581569/2292110095.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no3['nsum4']= no3.apply(lambda row: row['n1'] + row['n2']+row['n3']+row['n4'], axis=1)

# %%
##O1 defects
ndo1=no1[~no1.isin(npo1)].dropna()#o1 defects
for i in ndo1['Particle Identifier']:
    x=ndo1[ndo1['Particle Identifier']==i]['x'].values[0]
    z=ndo1[ndo1['Particle Identifier']==i]['z'].values[0]
    n=len(npo1[(abs(npo1['x']-x)<0.4)&(abs(npo1['z']-z)<0.4)])+ len(npo2[(abs(npo2['x']-x)<0.4)&(abs(npo2['z']-z)<0.2)])+len(npo3[(abs(npo3['x']-x)<0.4)&(abs(npo3['z']-z)<0.4)])   
    if n>1:
        print(i,n)
        ndo1 = ndo1.drop(index=[int(i-1)])
print(len(ndo1))

ndo1
# Out:
# 78674.0 8
# 91779.0 36
# 92139.0 39
# 92173.0 23
# 92279.0 39
# 100220.0 25
# 100240.0 8
# 100573.0 39
# 100620.0 35
# 100959.0 27
# 108239.0 39
# 108574.0 34
# 108959.0 39
# 3
#         Particle Identifier  Particle Type          x          y          z  \
# 92192               92193.0            3.0  52.949543  66.796120  73.380798
# 92233               92234.0            3.0  65.230921  64.679933  78.734016
# 100618             100619.0            3.0  68.521912  65.178136  81.327898
#
#          n1        d1   n2        d2   n3        d3   n4        d4   n5  \
# 92192   2.0  1.853750  2.0  1.960255  2.0  1.962024  5.0  2.139703  5.0
# 92233   2.0  1.885194  1.0  1.905415  5.0  2.172812  5.0  2.208976  3.0
# 100618  1.0  1.841216  1.0  1.864553  4.0  2.313411  3.0  2.333626  3.0
#
#               d5   n6        d6  nsum3  nsum4
# 92192   2.337524  4.0  2.369352    6.0   11.0
# 92233   2.278972  1.0  2.340112    8.0   13.0
# 100618  2.358080  4.0  2.358609    6.0    9.0

# %%
##O2 defects
ndo2=no2[~no2.isin(npo2)].dropna()#o2 defects
for i in ndo2['Particle Identifier']:
    x=ndo2[ndo2['Particle Identifier']==i]['x'].values[0]
    z=ndo2[ndo2['Particle Identifier']==i]['z'].values[0]
    n=len(npo1[(abs(npo1['x']-x)<0.4)&(abs(npo1['z']-z)<0.4)])+ len(npo2[(abs(npo2['x']-x)<0.4)&(abs(npo2['z']-z)<0.2)])+len(npo3[(abs(npo3['x']-x)<0.4)&(abs(npo3['z']-z)<0.4)])
    if n>1:
        ndo2 = ndo2.drop(index=[int(i-1)])
print(len(ndo2))

ndo2
# Out:
# 0
# Empty DataFrame
# Columns: [Particle Identifier, Particle Type, x, y, z, n1, d1, n2, d2, n3, d3, n4, d4, n5, d5, n6, d6, nsum3, nsum4]
# Index: []

# %%
##O3 defects
ndo3=no3[~no3.isin(npo3)].dropna()#o3 defects
for i in ndo3['Particle Identifier']:
    x=ndo3[ndo3['Particle Identifier']==i]['x'].values[0]
    z=ndo3[ndo3['Particle Identifier']==i]['z'].values[0]
    n=len(npo1[(abs(npo1['x']-x)<0.4)&(abs(npo1['z']-z)<0.4)])+ len(npo2[(abs(npo2['x']-x)<0.4)&(abs(npo2['z']-z)<0.2)])+len(npo3[(abs(npo3['x']-x)<0.4)&(abs(npo3['z']-z)<0.4)])
    if n>1:
        ndo3 = ndo3.drop(index=[int(i-1)])
print(len(ndo3))

ndo3
# Out:
# 2
#         Particle Identifier  Particle Type          x          y          z  \
# 100216             100217.0            5.0  66.993332  65.749813  77.941025
# 100571             100572.0            5.0  52.179089  68.468456  74.820836
#
#          n1        d1   n2        d2   n3        d3   n4        d4   n5  \
# 100216  2.0  1.860851  1.0  1.862509  3.0  2.208976  4.0  2.536901  1.0
# 100571  2.0  1.847566  1.0  1.848671  3.0  2.126353  2.0  2.145573  3.0
#
#               d5   n6        d6  nsum3  nsum4
# 100216  2.573729  3.0  2.601188    6.0   10.0
# 100571  2.337524  3.0  2.536105    6.0    8.0

# %%
defects=pd.concat([ndga1,ndga2,ndo1,ndo2,ndo3])
# prepare output folder
#if not os.path.isdir('frame100'):
#    os.mkdir('frame100')
#defects.to_csv('frame100/npt_defects100.csv') 
defects.to_csv('defects8.csv')
