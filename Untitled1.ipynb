# %%
import lammps_logfile
import matplotlib.pyplot as plt
path='/Users/ruhe/Desktop/ga2o3/beta/Swelling/Ga_vacancy_interstitial/log/small/'
fn=path+'v1/npt_vacancy.log'
log = lammps_logfile.File(fn)
plt.plot((log.get("Lx")-log.get("Lx")[0])/log.get("Lx")[0])
plt.plot((log.get("Ly")-log.get("Ly")[0])/log.get("Ly")[0])

fn=path+'v1/2v_i/npt_vacancy.log'
log = lammps_logfile.File(fn)
plt.plot((log.get("Lx")-log.get("Lx")[0])/log.get("Lx")[0])
plt.plot((log.get("Ly")-log.get("Ly")[0])/log.get("Ly")[0])

# %%
plt.plot(log.get("v_ape"))
fn=path+'v4/npt_vacancy.log'
log = lammps_logfile.File(fn)
plt.plot(log.get("v_ape"))

# %%
fn=path+'v2/npt_vacancy.log'
log = lammps_logfile.File(fn)
plt.plot((log.get("Lx")-log.get("Lx")[0])/log.get("Lx")[0])

plt.plot((log.get("Ly")-log.get("Ly")[0])/log.get("Ly")[0])

# %%
fn=path+'v3/npt_vacancy.log'
log = lammps_logfile.File(fn)
#plt.plot((log.get("Lx")-log.get("Lx")[0])/log.get("Lx")[0])
#plt.plot((log.get("Ly")-log.get("Ly")[0])/log.get("Ly")[0])

fn=path+'v4/npt_vacancy.log'
log = lammps_logfile.File(fn)
plt.plot((log.get("Lx")-log.get("Lx")[0])/log.get("Lx")[0])
plt.plot((log.get("Ly")-log.get("Ly")[0])/log.get("Ly")[0])

# %%
path='/Users/ruhe/Desktop/ga2o3/beta/Swelling/Ga_vacancy_interstitial/log/medium/'
fn=path+'v2/npt_vacancy.log'
log = lammps_logfile.File(fn)
plt.plot((log.get("Lx")-log.get("Lx")[0])/log.get("Lx")[0])
plt.plot((log.get("Ly")-log.get("Ly")[0])/log.get("Ly")[0])
#plt.plot((log.get("Lz")-log.get("Lz")[0])/log.get("Lz")[0])

# %%
path='/Users/ruhe/Desktop/ga2o3/beta/Swelling/Ga_vacancy_interstitial/log/medium/'
fn=path+'v8/npt_vacancy.log'
log = lammps_logfile.File(fn)
plt.plot((log.get("Lx")-log.get("Lx")[0])/log.get("Lx")[0])
plt.plot((log.get("Ly")-log.get("Ly")[0])/log.get("Ly")[0])

# %%
path='/home/heruhe/Desktop/Ga2o3/Frenkelpair/GaFPA/GaFP_nvt/nptlog'
colors=['#1f77b4', '#ff7f0e', 'g', 'r', (0.5, 0.2, 0.8), (0.2, 0.6, 0.5, 0.8), 'y']
j=0
sx=[]
sy=[]
sz=[]
fpl=[i for i in range(1,1000,10)]
for i in fpl:    
    fn=path+'/npt_{}.log'.format(i)
    log = lammps_logfile.File(fn)
    strainx=(log.get("Lx")-log.get("Lx")[0])/log.get("Lx")[0]
    mstrainx=sum(strainx[100:])/len(strainx[100:])
    mstrainx=np.mean(strainx[100:])
    strainy=(log.get("Ly")-log.get("Ly")[0])/log.get("Ly")[0]
    mstrainy=sum(strainy[100:])/len(strainy[100:])
    strainz=(log.get("Lz")-log.get("Lz")[0])/log.get("Lz")[0]
    mstrainz=sum(strainz[100:])/len(strainz[100:])
    sx.append(mstrainx)
    sy.append(mstrainy)
    sz.append(mstrainz)
plt.plot(fpl,sx)
plt.plot(fpl,sy)
plt.plot(fpl,sz)
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
path='/home/heruhe/Desktop/Ga2o3/Frenkelpair/GaFPA/GaFP_nvt/npt'
colors=['#1f77b4', '#ff7f0e', 'g', 'r', (0.5, 0.2, 0.8), (0.2, 0.6, 0.5, 0.8), 'y']
j=0
for i in [10,50,100]:
    
    fn=path+'/npt_{}.log'.format(i)
    log = lammps_logfile.File(fn)
    plt.plot((log.get("Lx")-log.get("Lx")[0])/log.get("Lx")[0],color=colors[j],label='{}.FP'.format(i))
    plt.plot((log.get("Ly")-log.get("Ly")[0])/log.get("Ly")[0],color=colors[j])
    j=j+1
plt.legend()

# %%
path='/home/heruhe/Desktop/Ga2o3/Frenkelpair/GaFPA/npt/test/log'


lx0=24.2998
ly0=24.773
lz0=23.6007
lx=[]
ly=[]
lz=[]
fpl=[i for i in range(1,100)]
for i in fpl:
    fn=path+'/lammps.stdout{}'.format(i)
    log = lammps_logfile.File(fn)
    lx.append((np.mean(log.get("Lx")[2:-1])-lx0)/lx0)
    ly.append((np.mean(log.get("Ly")[2:-1])-ly0)/ly0)
    lz.append((np.mean(log.get("Lz")[2:-1])-lz0)/lz0)
plt.plot(fpl,lx,label='lx')
plt.plot(fpl,ly,label='ly')  
plt.plot(fpl,lz,label='lz')

# %%
path='/home/heruhe/Desktop/Ga2o3/Frenkelpair/GaFPA/npt/test2/log'


lx0=24.2998
ly0=24.773
lz0=23.6007
lx=[]
ly=[]
lz=[]
fpl=[i for i in range(1,100)]
for i in fpl:
    fn=path+'/lammps.stdout{}'.format(i)
    log = lammps_logfile.File(fn)
    lx.append((np.mean(log.get("Lx")[2:-1])-lx0)/lx0)
    ly.append((np.mean(log.get("Ly")[2:-1])-ly0)/ly0)
    lz.append((np.mean(log.get("Lz")[2:-1])-lz0)/lz0)
plt.plot(fpl,lx,label='lx')
plt.plot(fpl,ly,label='ly')  
plt.plot(fpl,lz,label='lz')

# %%
path='/home/heruhe/Desktop/Ga2o3/Frenkelpair/GaFPA/npt/test3/log'


lx0=24.2998
ly0=24.773
lz0=23.6007
lx=[]
ly=[]
lz=[]
fpl=[i for i in range(1,480)]
for i in fpl:
    fn=path+'/lammps.stdout{}'.format(i)
    log = lammps_logfile.File(fn)
    lx.append((np.mean(log.get("Lx")[100:-1])-lx0)/lx0)
    ly.append((np.mean(log.get("Ly")[100:-1])-ly0)/ly0)
    lz.append((np.mean(log.get("Lz")[100:-1])-lz0)/lz0)
plt.plot(fpl,lx,label='lx')
plt.plot(fpl,ly,label='ly')  
plt.plot(fpl,lz,label='lz')

# %%
path='/home/heruhe/Desktop/Ga2o3/Frenkelpair/GaFPA/npt/test3/log'
colors=['#1f77b4', '#ff7f0e', 'g', 'r', (0.5, 0.2, 0.8), (0.2, 0.6, 0.5, 0.8), 'y']
j=0
for i in [20]:
    
    fn=path+'/lammps.stdout{}'.format(i)
    log = lammps_logfile.File(fn)
    plt.plot(log.get("Lx"))
    plt.plot(log.get("Ly"))
    j=j+1
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
